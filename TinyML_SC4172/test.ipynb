# %%
print ("Jupyter is working")
# Out:
# Jupyter is working

# %%
# Example libraries you expect
# libraries = ["numpy", "keras", "matplotlib", "tensorflow"]

# for lib in libraries:
#     try:
#         __import__(lib)
#         print(f"{lib} ✅ imported")
#     except ImportError:
#         print(f"{lib} ❌ NOT installed")

import tensorflow as tf
msg = tf.constant("TensorFlow is working")
tf.print(msg)
# Out:
# numpy ✅ imported
# keras ✅ imported
# matplotlib ✅ imported
# tensorflow ✅ imported
# TensorFlow is working
